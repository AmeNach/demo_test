# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Amel Nait Achour**<br>
# Student

# %% [markdown]
# *I am interested in data science because it is the starting point for building AI powered algorithms for different computer vision applications, as well as my desire to work for social endeavours*

# %% [markdown]
# ### My code in the following cell is used to display a random distribution of 200 samples

# %%
import numpy as np 
import matplotlib.pyplot as plt



num_samples = 200
X = np.random.random(num_samples)
y= np.random.random(num_samples)

plt.scatter(X, y)

# %% [markdown]
# This cell includes: <br>
# * Bulleted list
# * Hyperlink: __[Link to this notebook](https://eu-de.dataplatform.cloud.ibm.com/analytics/notebooks/v2/d67d50c9-2b65-40df-8171-ec09b0daa9e6/view?access_token=eb6855b1ef10e557ea9ade4a7621e417475a79337b45b434ad0a090dc1c55fe7)__
# * image![download.png](attachment:download.png)
